# %%
import random
import time
import requests
from bs4 import BeautifulSoup, NavigableString, Tag

BASE = "https://www.trismegistos.org/text/{id3}"

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/124.0 Safari/537.36"
    ),
    "Accept-Language": "en,fr;q=0.9",
}

def extract_language(html: str) -> str | None:
    """
    Tente d'extraire la valeur affichée pour 'Language/script:'.
    On cherche le <span class="semibold">Language/script:</span>
    puis on lit le texte qui suit dans le même <p>.
    """
    soup = BeautifulSoup(html, "lxml")

    # 1) Heuristique robuste : trouver le span portant l'étiquette
    spans = soup.select("span.semibold")
    label_span = None
    for sp in spans:
        if sp.get_text(strip=True).lower() == "language/script:":
            label_span = sp
            break

    if label_span:
        # Valeur la plus fiable : concat des siblings (texte/éléments) après le span
        parts = []
        for sib in label_span.next_siblings:
            if isinstance(sib, NavigableString):
                parts.append(str(sib))
            elif isinstance(sib, Tag):
                parts.append(sib.get_text(" ", strip=True))
        value = " ".join(" ".join(parts).split()).strip(" :\u00a0-")  # normalise espaces
        if value:
            return value

        # Repli : prendre le texte du <p> parent en enlevant l’étiquette
        p = label_span.find_parent("p")
        if p:
            full = " ".join(p.get_text(" ", strip=True).split())
            for prefix in ("Language/script:", "Language/script"):
                if full.startswith(prefix):
                    return full[len(prefix):].strip(" :\u00a0-") or None

    # CSS : #text-details > p:nth-child(4) > span  -> lire le texte du parent <p>
    try:
        sp = soup.select_one("#text-details > p:nth-child(4) > span")
        if sp and sp.get_text(strip=True).lower().startswith("language/script"):
            p = sp.find_parent("p")
            if p:
                full = " ".join(p.get_text(" ", strip=True).split())
                return full.split(":", 1)[1].strip() if ":" in full else None
    except Exception:
        pass

    # XPath équivalents ne sont pas utilisés directement par bs4,
    # mais on a déjà couvert les chemins ci-dessus.
    return None


def check_pages(ids: list[int]) -> list[dict]:
    results = []
    for n in ids:
        id3 = f"{n:03d}"  # zéro-remplissage comme dans 001 … 100
        url = BASE.format(id3=id3)
        row = {"id": n, "id3": id3, "url": url, "status": None, "language": None, "is_greek": None, "error": None}
        try:
            resp = requests.get(url, headers=HEADERS, timeout=15)
            row["status"] = resp.status_code
            if resp.status_code == 200:
                lang = extract_language(resp.text)
                row["language"] = lang
                row["is_greek"] = (lang is not None) and (lang.strip().lower().startswith("greek"))
            else:
                row["error"] = f"HTTP {resp.status_code}"
        except requests.RequestException as e:
            row["error"] = str(e)
        results.append(row)

        # Petite pause polie pour éviter de surcharger le site
        time.sleep(random.uniform(0.6, 1.4))
    return results


if __name__ == "__main__":
    # 20 entiers aléatoires entre 0 et 100 (sans doublons).
    # Si vous voulez autoriser des doublons, remplacez par: [random.randint(0, 100) for _ in range(20)]
    sample_ids = random.sample(range(0, 101), 20)

    data = check_pages(sample_ids)

    # Affichage lisible
    ok = 0
    print(f"{'ID':>3}  {'URL':<45} {'HTTP':<4}  {'Language':<20}  Greek?")
    print("-" * 90)
    for r in data:
        mark = "✓" if r["is_greek"] else ("-" if r["is_greek"] is None else "✗")
        lang = r["language"] or ""
        http = r["status"] if r["status"] is not None else ""
        print(f"{r['id']:>3}  {r['url']:<45} {str(http):<4}  {lang:<20}  {mark}")
        if r["is_greek"]:
            ok += 1
    print("-" * 90)
    print(f"Pages où Language/script == 'Greek' (ou commence par 'Greek') : {ok}/{len(data)}")
# Out:
#  ID  URL                                           HTTP  Language              Greek?
# ------------------------------------------------------------------------------------------
#  82  https://www.trismegistos.org/text/082         200   Greek                 ✓
#  38  https://www.trismegistos.org/text/038         200   Demotic               ✗
#  15  https://www.trismegistos.org/text/015         200   Greek                 ✓
#   3  https://www.trismegistos.org/text/003         200   Greek                 ✓
#  25  https://www.trismegistos.org/text/025         200   Demotic               ✗
#  77  https://www.trismegistos.org/text/077         200   Greek                 ✓
#  16  https://www.trismegistos.org/text/016         200   Greek                 ✓
#  66  https://www.trismegistos.org/text/066         200   Demotic / Greek       ✗
#  88  https://www.trismegistos.org/text/088         200   Greek                 ✓
#  69  https://www.trismegistos.org/text/069         200   Greek                 ✓
#  44  https://www.trismegistos.org/text/044         200   Demotic               ✗
#   1  https://www.trismegistos.org/text/001         200   Greek                 ✓
#   0  https://www.trismegistos.org/text/000         200   Greek                 ✓
#  97  https://www.trismegistos.org/text/097         200   Demotic               ✗
#  76  https://www.trismegistos.org/text/076         200   Greek                 ✓
#  35  https://www.trismegistos.org/text/035         200   Demotic               ✗
#  73  https://www.trismegistos.org/text/073         200   Greek                 ✓
#  42  https://www.trismegistos.org/text/042         200   Demotic               ✗
#  84  https://www.trismegistos.org/text/084         200   Greek                 ✓
#  12  https://www.trismegistos.org/text/012         200   Greek                 ✓
# ------------------------------------------------------------------------------------------
# Pages où Language/script == 'Greek' (ou commence par 'Greek') : 13/20

# %%
# !python scrape_trismegistos_geojson.py --start 1500 --end 2000 --out out --delay 0.5 --resume
# Out:
# 2025-10-29 10:15:04,284 | INFO | ID 1500 → sauvegardé: out/id_1500.json
# 2025-10-29 10:15:04,972 | INFO | ID 1501 → sauvegardé: out/id_1501.json
# 2025-10-29 10:15:05,659 | INFO | ID 1502 → sauvegardé: out/id_1502.json
# 2025-10-29 10:15:06,348 | INFO | ID 1503 → sauvegardé: out/id_1503.json
# 2025-10-29 10:15:07,038 | INFO | ID 1504 → sauvegardé: out/id_1504.json
# 2025-10-29 10:15:07,724 | INFO | ID 1505 → sauvegardé: out/id_1505.json
# 2025-10-29 10:15:08,403 | INFO | ID 1506 → sauvegardé: out/id_1506.json
# 2025-10-29 10:15:09,087 | INFO | ID 1507 → sauvegardé: out/id_1507.json
# 2025-10-29 10:15:09,761 | INFO | ID 1508 → sauvegardé: out/id_1508.json
# 2025-10-29 10:15:10,449 | INFO | ID 1509 → sauvegardé: out/id_1509.json
# 2025-10-29 10:15:11,138 | INFO | ID 1510 → sauvegardé: out/id_1510.json
# 2025-10-29 10:15:11,811 | INFO | ID 1511 → sauvegardé: out/id_1511.json
# 2025-10-29 10:15:12,484 | INFO | ID 1512 → sauvegardé: out/id_1512.json
# 2025-10-29 10:15:13,172 | INFO | ID 1513 → sauvegardé: out/id_1513.json
# 2025-10-29 10:15:13,863 | INFO | ID 1514 → sauvegardé: out/id_1514.json
# 2025-10-29 10:15:14,551 | INFO | ID 1515 → sauvegardé: out/id_1515.json
# 2025-10-29 10:15:15,224 | INFO | ID 1516 → sauvegardé: out/id_1516.json
# 2025-10-29 10:15:15,912 | INFO | ID 1517 → sauvegardé: out/id_1517.json
# 2025-10-29 10:15:16,601 | INFO | ID 1518 → sauvegardé: out/id_1518.json
# 2025-10-29 10:15:17,273 | INFO | ID 1519 → sauvegardé: out/id_1519.json
# 2025-10-29 10:15:17,946 | INFO | ID 1520 → sauvegardé: out/id_1520.json
# 2025-10-29 10:15:18,622 | INFO | ID 1521 → sauvegardé: out/id_1521.json
# 2025-10-29 10:15:19,284 | INFO | ID 1522 → sauvegardé: out/id_1522.json
# 2025-10-29 10:15:19,968 | INFO | ID 1523 → sauvegardé: out/id_1523.json
# 2025-10-29 10:15:20,640 | INFO | ID 1524 → sauvegardé: out/id_1524.json
# 2025-10-29 10:15:21,329 | INFO | ID 1525 → sauvegardé: out/id_1525.json
# 2025-10-29 10:15:22,018 | INFO | ID 1526 → sauvegardé: out/id_1526.json
# 2025-10-29 10:15:22,708 | INFO | ID 1527 → sauvegardé: out/id_1527.json
# 2025-10-29 10:15:23,380 | INFO | ID 1528 → sauvegardé: out/id_1528.json
# 2025-10-29 10:15:24,068 | INFO | ID 1529 → sauvegardé: out/id_1529.json
# 2025-10-29 10:15:24,757 | INFO | ID 1530 → sauvegardé: out/id_1530.json
# 2025-10-29 10:15:25,430 | INFO | ID 1531 → sauvegardé: out/id_1531.json
# 2025-10-29 10:15:26,105 | INFO | ID 1532 → sauvegardé: out/id_1532.json
# 2025-10-29 10:15:26,792 | INFO | ID 1533 → sauvegardé: out/id_1533.json
# 2025-10-29 10:15:27,480 | INFO | ID 1534 → sauvegardé: out/id_1534.json
# 2025-10-29 10:15:28,168 | INFO | ID 1535 → sauvegardé: out/id_1535.json
# 2025-10-29 10:15:28,858 | INFO | ID 1536 → sauvegardé: out/id_1536.json
# 2025-10-29 10:15:29,548 | INFO | ID 1537 → sauvegardé: out/id_1537.json
# 2025-10-29 10:15:30,236 | INFO | ID 1538 → sauvegardé: out/id_1538.json
# 2025-10-29 10:15:30,910 | INFO | ID 1539 → sauvegardé: out/id_1539.json
# 2025-10-29 10:15:31,596 | INFO | ID 1540 → sauvegardé: out/id_1540.json
# 2025-10-29 10:15:32,270 | INFO | ID 1541 → sauvegardé: out/id_1541.json
# 2025-10-29 10:15:32,943 | INFO | ID 1542 → sauvegardé: out/id_1542.json
# 2025-10-29 10:15:33,632 | INFO | ID 1543 → sauvegardé: out/id_1543.json
# 2025-10-29 10:15:34,321 | INFO | ID 1544 → sauvegardé: out/id_1544.json
# 2025-10-29 10:15:35,010 | INFO | ID 1545 → sauvegardé: out/id_1545.json
# 2025-10-29 10:15:35,700 | INFO | ID 1546 → sauvegardé: out/id_1546.json
# 2025-10-29 10:15:36,388 | INFO | ID 1547 → sauvegardé: out/id_1547.json
# 2025-10-29 10:15:37,075 | INFO | ID 1548 → sauvegardé: out/id_1548.json
# 2025-10-29 10:15:37,748 | INFO | ID 1549 → sauvegardé: out/id_1549.json
# 2025-10-29 10:15:38,411 | INFO | ID 1550 → sauvegardé: out/id_1550.json
# 2025-10-29 10:15:39,094 | INFO | ID 1551 → sauvegardé: out/id_1551.json
# 2025-10-29 10:15:39,768 | INFO | ID 1552 → sauvegardé: out/id_1552.json
# 2025-10-29 10:15:40,457 | INFO | ID 1553 → sauvegardé: out/id_1553.json
# 2025-10-29 10:15:41,146 | INFO | ID 1554 → sauvegardé: out/id_1554.json
# 2025-10-29 10:15:41,834 | INFO | ID 1555 → sauvegardé: out/id_1555.json
# 2025-10-29 10:15:42,522 | INFO | ID 1556 → sauvegardé: out/id_1556.json
# 2025-10-29 10:15:43,211 | INFO | ID 1557 → sauvegardé: out/id_1557.json
# 2025-10-29 10:15:43,884 | INFO | ID 1558 → sauvegardé: out/id_1558.json
# 2025-10-29 10:15:44,557 | INFO | ID 1559 → sauvegardé: out/id_1559.json
# 2025-10-29 10:15:45,231 | INFO | ID 1560 → sauvegardé: out/id_1560.json
# 2025-10-29 10:15:45,920 | INFO | ID 1561 → sauvegardé: out/id_1561.json
# 2025-10-29 10:15:46,596 | INFO | ID 1562 → sauvegardé: out/id_1562.json
# 2025-10-29 10:15:47,281 | INFO | ID 1563 → sauvegardé: out/id_1563.json
# 2025-10-29 10:15:47,970 | INFO | ID 1564 → sauvegardé: out/id_1564.json
# 2025-10-29 10:15:48,644 | INFO | ID 1565 → sauvegardé: out/id_1565.json
# 2025-10-29 10:15:50,364 | INFO | ID 1566 → sauvegardé: out/id_1566.json
# 2025-10-29 10:15:51,052 | INFO | ID 1567 → sauvegardé: out/id_1567.json
# 2025-10-29 10:15:51,729 | INFO | ID 1568 → sauvegardé: out/id_1568.json
# 2025-10-29 10:15:52,416 | INFO | ID 1569 → sauvegardé: out/id_1569.json
# 2025-10-29 10:15:53,105 | INFO | ID 1570 → sauvegardé: out/id_1570.json
# 2025-10-29 10:15:53,794 | INFO | ID 1571 → sauvegardé: out/id_1571.json
# 2025-10-29 10:15:54,484 | INFO | ID 1572 → sauvegardé: out/id_1572.json
# 2025-10-29 10:15:55,171 | INFO | ID 1573 → sauvegardé: out/id_1573.json
# 2025-10-29 10:15:55,844 | INFO | ID 1574 → sauvegardé: out/id_1574.json
# 2025-10-29 10:15:56,532 | INFO | ID 1575 → sauvegardé: out/id_1575.json
# 2025-10-29 10:15:57,220 | INFO | ID 1576 → sauvegardé: out/id_1576.json
# 2025-10-29 10:15:57,893 | INFO | ID 1577 → sauvegardé: out/id_1577.json
# 2025-10-29 10:15:58,568 | INFO | ID 1578 → sauvegardé: out/id_1578.json
# 2025-10-29 10:15:59,241 | INFO | ID 1579 → sauvegardé: out/id_1579.json
# 2025-10-29 10:15:59,928 | INFO | ID 1580 → sauvegardé: out/id_1580.json
# 2025-10-29 10:16:00,601 | INFO | ID 1581 → sauvegardé: out/id_1581.json
# 2025-10-29 10:16:01,291 | INFO | ID 1582 → sauvegardé: out/id_1582.json
# 2025-10-29 10:16:01,965 | INFO | ID 1583 → sauvegardé: out/id_1583.json
# 2025-10-29 10:16:02,651 | INFO | ID 1584 → sauvegardé: out/id_1584.json
# 2025-10-29 10:16:03,326 | INFO | ID 1585 → sauvegardé: out/id_1585.json
# 2025-10-29 10:16:04,015 | INFO | ID 1586 → sauvegardé: out/id_1586.json
# 2025-10-29 10:16:04,703 | INFO | ID 1587 → sauvegardé: out/id_1587.json
# 2025-10-29 10:16:05,393 | INFO | ID 1588 → sauvegardé: out/id_1588.json
# 2025-10-29 10:16:06,080 | INFO | ID 1589 → sauvegardé: out/id_1589.json
# 2025-10-29 10:16:06,769 | INFO | ID 1590 → sauvegardé: out/id_1590.json
# 2025-10-29 10:16:07,456 | INFO | ID 1591 → sauvegardé: out/id_1591.json
# 2025-10-29 10:16:08,130 | INFO | ID 1592 → sauvegardé: out/id_1592.json
# 2025-10-29 10:16:08,803 | INFO | ID 1593 → sauvegardé: out/id_1593.json
# 2025-10-29 10:16:09,492 | INFO | ID 1594 → sauvegardé: out/id_1594.json
# 2025-10-29 10:16:10,181 | INFO | ID 1595 → sauvegardé: out/id_1595.json
# 2025-10-29 10:16:10,870 | INFO | ID 1596 → sauvegardé: out/id_1596.json
# 2025-10-29 10:16:11,558 | INFO | ID 1597 → sauvegardé: out/id_1597.json
# 2025-10-29 10:16:12,231 | INFO | ID 1598 → sauvegardé: out/id_1598.json
# 2025-10-29 10:16:12,904 | INFO | ID 1599 → sauvegardé: out/id_1599.json
# 2025-10-29 10:16:13,579 | INFO | ID 1600 → sauvegardé: out/id_1600.json
# 2025-10-29 10:16:14,268 | INFO | ID 1601 → sauvegardé: out/id_1601.json
# 2025-10-29 10:16:14,955 | INFO | ID 1602 → sauvegardé: out/id_1602.json
# 2025-10-29 10:16:15,631 | INFO | ID 1603 → sauvegardé: out/id_1603.json
# 2025-10-29 10:16:16,302 | INFO | ID 1604 → sauvegardé: out/id_1604.json
# 2025-10-29 10:16:16,990 | INFO | ID 1605 → sauvegardé: out/id_1605.json
# 2025-10-29 10:16:17,664 | INFO | ID 1606 → sauvegardé: out/id_1606.json
# 2025-10-29 10:16:18,337 | INFO | ID 1607 → sauvegardé: out/id_1607.json
# 2025-10-29 10:16:19,010 | INFO | ID 1608 → sauvegardé: out/id_1608.json
# 2025-10-29 10:16:19,698 | INFO | ID 1609 → sauvegardé: out/id_1609.json
# 2025-10-29 10:16:20,388 | INFO | ID 1610 → sauvegardé: out/id_1610.json
# 2025-10-29 10:16:21,062 | INFO | ID 1611 → sauvegardé: out/id_1611.json
# 2025-10-29 10:16:21,749 | INFO | ID 1612 → sauvegardé: out/id_1612.json
# 2025-10-29 10:16:22,439 | INFO | ID 1613 → sauvegardé: out/id_1613.json
# 2025-10-29 10:16:23,113 | INFO | ID 1614 → sauvegardé: out/id_1614.json
# 2025-10-29 10:16:23,801 | INFO | ID 1615 → sauvegardé: out/id_1615.json
# 2025-10-29 10:16:24,493 | INFO | ID 1616 → sauvegardé: out/id_1616.json
# 2025-10-29 10:16:25,180 | INFO | ID 1617 → sauvegardé: out/id_1617.json
# 2025-10-29 10:16:25,868 | INFO | ID 1618 → sauvegardé: out/id_1618.json
# 2025-10-29 10:16:26,558 | INFO | ID 1619 → sauvegardé: out/id_1619.json
# 2025-10-29 10:16:27,246 | INFO | ID 1620 → sauvegardé: out/id_1620.json
# 2025-10-29 10:16:27,920 | INFO | ID 1621 → sauvegardé: out/id_1621.json
# 2025-10-29 10:16:28,610 | INFO | ID 1622 → sauvegardé: out/id_1622.json
# 2025-10-29 10:16:29,297 | INFO | ID 1623 → sauvegardé: out/id_1623.json
# 2025-10-29 10:16:29,985 | INFO | ID 1624 → sauvegardé: out/id_1624.json
# 2025-10-29 10:16:30,659 | INFO | ID 1625 → sauvegardé: out/id_1625.json
# 2025-10-29 10:16:31,335 | INFO | ID 1626 → sauvegardé: out/id_1626.json
# 2025-10-29 10:16:32,020 | INFO | ID 1627 → sauvegardé: out/id_1627.json
# 2025-10-29 10:16:32,695 | INFO | ID 1628 → sauvegardé: out/id_1628.json
# 2025-10-29 10:16:33,384 | INFO | ID 1629 → sauvegardé: out/id_1629.json
# 2025-10-29 10:16:34,070 | INFO | ID 1630 → sauvegardé: out/id_1630.json
# 2025-10-29 10:16:34,760 | INFO | ID 1631 → sauvegardé: out/id_1631.json
# 2025-10-29 10:16:35,449 | INFO | ID 1632 → sauvegardé: out/id_1632.json
# 2025-10-29 10:16:36,123 | INFO | ID 1633 → sauvegardé: out/id_1633.json
# 2025-10-29 10:16:36,809 | INFO | ID 1634 → sauvegardé: out/id_1634.json
# 2025-10-29 10:16:37,483 | INFO | ID 1635 → sauvegardé: out/id_1635.json
# 2025-10-29 10:16:38,157 | INFO | ID 1636 → sauvegardé: out/id_1636.json
# 2025-10-29 10:16:38,847 | INFO | ID 1637 → sauvegardé: out/id_1637.json
# 2025-10-29 10:16:39,534 | INFO | ID 1638 → sauvegardé: out/id_1638.json
# 2025-10-29 10:16:40,208 | INFO | ID 1639 → sauvegardé: out/id_1639.json
# 2025-10-29 10:16:40,897 | INFO | ID 1640 → sauvegardé: out/id_1640.json
# 2025-10-29 10:16:41,559 | INFO | ID 1641 → sauvegardé: out/id_1641.json
# 2025-10-29 10:16:42,225 | INFO | ID 1642 → sauvegardé: out/id_1642.json
# 2025-10-29 10:16:42,900 | INFO | ID 1643 → sauvegardé: out/id_1643.json
# 2025-10-29 10:16:43,572 | INFO | ID 1644 → sauvegardé: out/id_1644.json
# 2025-10-29 10:16:44,247 | INFO | ID 1645 → sauvegardé: out/id_1645.json
# 2025-10-29 10:16:44,919 | INFO | ID 1646 → sauvegardé: out/id_1646.json
# 2025-10-29 10:16:45,606 | INFO | ID 1647 → sauvegardé: out/id_1647.json
# 2025-10-29 10:16:46,280 | INFO | ID 1648 → sauvegardé: out/id_1648.json
# 2025-10-29 10:16:46,941 | INFO | ID 1649 → sauvegardé: out/id_1649.json
# 2025-10-29 10:16:47,627 | INFO | ID 1650 → sauvegardé: out/id_1650.json
# 2025-10-29 10:16:48,316 | INFO | ID 1651 → sauvegardé: out/id_1651.json
# 2025-10-29 10:16:48,988 | INFO | ID 1652 → sauvegardé: out/id_1652.json
# 2025-10-29 10:16:49,663 | INFO | ID 1653 → sauvegardé: out/id_1653.json
# 2025-10-29 10:16:50,351 | INFO | ID 1654 → sauvegardé: out/id_1654.json
# 2025-10-29 10:16:51,039 | INFO | ID 1655 → sauvegardé: out/id_1655.json
# 2025-10-29 10:16:51,712 | INFO | ID 1656 → sauvegardé: out/id_1656.json
# 2025-10-29 10:16:52,401 | INFO | ID 1657 → sauvegardé: out/id_1657.json
# 2025-10-29 10:16:53,079 | INFO | ID 1658 → sauvegardé: out/id_1658.json
# 2025-10-29 10:16:53,765 | INFO | ID 1659 → sauvegardé: out/id_1659.json
# 2025-10-29 10:16:54,452 | INFO | ID 1660 → sauvegardé: out/id_1660.json
# 2025-10-29 10:16:55,141 | INFO | ID 1661 → sauvegardé: out/id_1661.json
# 2025-10-29 10:16:55,813 | INFO | ID 1662 → sauvegardé: out/id_1662.json
# 2025-10-29 10:16:56,477 | INFO | ID 1663 → sauvegardé: out/id_1663.json
# 2025-10-29 10:16:57,160 | INFO | ID 1664 → sauvegardé: out/id_1664.json
# 2025-10-29 10:16:57,873 | INFO | ID 1665 → sauvegardé: out/id_1665.json
# 2025-10-29 10:16:58,555 | INFO | ID 1666 → sauvegardé: out/id_1666.json
# 2025-10-29 10:16:59,231 | INFO | ID 1667 → sauvegardé: out/id_1667.json
# 2025-10-29 10:16:59,915 | INFO | ID 1668 → sauvegardé: out/id_1668.json
# 2025-10-29 10:17:00,588 | INFO | ID 1669 → sauvegardé: out/id_1669.json
# 2025-10-29 10:17:01,261 | INFO | ID 1670 → sauvegardé: out/id_1670.json
# 2025-10-29 10:17:01,951 | INFO | ID 1671 → sauvegardé: out/id_1671.json
# 2025-10-29 10:17:02,639 | INFO | ID 1672 → sauvegardé: out/id_1672.json
# 2025-10-29 10:17:03,313 | INFO | ID 1673 → sauvegardé: out/id_1673.json
# 2025-10-29 10:17:04,000 | INFO | ID 1674 → sauvegardé: out/id_1674.json
# 2025-10-29 10:17:04,673 | INFO | ID 1675 → sauvegardé: out/id_1675.json
# 2025-10-29 10:17:05,347 | INFO | ID 1676 → sauvegardé: out/id_1676.json
# 2025-10-29 10:17:06,020 | INFO | ID 1677 → sauvegardé: out/id_1677.json
# 2025-10-29 10:17:06,708 | INFO | ID 1678 → sauvegardé: out/id_1678.json
# 2025-10-29 10:17:07,380 | INFO | ID 1679 → sauvegardé: out/id_1679.json
# 2025-10-29 10:17:08,055 | INFO | ID 1680 → sauvegardé: out/id_1680.json
# 2025-10-29 10:17:08,714 | INFO | ID 1681 → sauvegardé: out/id_1681.json
# 2025-10-29 10:17:09,376 | INFO | ID 1682 → sauvegardé: out/id_1682.json
# 2025-10-29 10:17:10,057 | INFO | ID 1683 → sauvegardé: out/id_1683.json
# 2025-10-29 10:17:10,729 | INFO | ID 1684 → sauvegardé: out/id_1684.json
# 2025-10-29 10:17:11,403 | INFO | ID 1685 → sauvegardé: out/id_1685.json
# 2025-10-29 10:17:12,092 | INFO | ID 1686 → sauvegardé: out/id_1686.json
# 2025-10-29 10:17:12,781 | INFO | ID 1687 → sauvegardé: out/id_1687.json
# 2025-10-29 10:17:13,470 | INFO | ID 1688 → sauvegardé: out/id_1688.json
# 2025-10-29 10:17:14,158 | INFO | ID 1689 → sauvegardé: out/id_1689.json
# 2025-10-29 10:17:14,831 | INFO | ID 1690 → sauvegardé: out/id_1690.json
# 2025-10-29 10:17:15,520 | INFO | ID 1691 → sauvegardé: out/id_1691.json
# 2025-10-29 10:17:16,208 | INFO | ID 1692 → sauvegardé: out/id_1692.json
# 2025-10-29 10:17:16,898 | INFO | ID 1693 → sauvegardé: out/id_1693.json
# 2025-10-29 10:17:17,586 | INFO | ID 1694 → sauvegardé: out/id_1694.json
# 2025-10-29 10:17:18,259 | INFO | ID 1695 → sauvegardé: out/id_1695.json
# 2025-10-29 10:17:18,946 | INFO | ID 1696 → sauvegardé: out/id_1696.json
# 2025-10-29 10:17:19,607 | INFO | ID 1697 → sauvegardé: out/id_1697.json
# 2025-10-29 10:17:20,293 | INFO | ID 1698 → sauvegardé: out/id_1698.json
# 2025-10-29 10:17:20,982 | INFO | ID 1699 → sauvegardé: out/id_1699.json
# 2025-10-29 10:17:21,655 | INFO | ID 1700 → sauvegardé: out/id_1700.json
# 2025-10-29 10:17:22,328 | INFO | ID 1701 → sauvegardé: out/id_1701.json
# 2025-10-29 10:17:23,016 | INFO | ID 1702 → sauvegardé: out/id_1702.json
# 2025-10-29 10:17:23,690 | INFO | ID 1703 → sauvegardé: out/id_1703.json
# 2025-10-29 10:17:24,380 | INFO | ID 1704 → sauvegardé: out/id_1704.json
# 2025-10-29 10:17:25,067 | INFO | ID 1705 → sauvegardé: out/id_1705.json
# 2025-10-29 10:17:25,756 | INFO | ID 1706 → sauvegardé: out/id_1706.json
# 2025-10-29 10:17:26,429 | INFO | ID 1707 → sauvegardé: out/id_1707.json
# 2025-10-29 10:17:27,118 | INFO | ID 1708 → sauvegardé: out/id_1708.json
# 2025-10-29 10:17:27,809 | INFO | ID 1709 → sauvegardé: out/id_1709.json
# 2025-10-29 10:17:28,494 | INFO | ID 1710 → sauvegardé: out/id_1710.json
# 2025-10-29 10:17:29,170 | INFO | ID 1711 → sauvegardé: out/id_1711.json
# 2025-10-29 10:17:29,858 | INFO | ID 1712 → sauvegardé: out/id_1712.json
# 2025-10-29 10:17:30,547 | INFO | ID 1713 → sauvegardé: out/id_1713.json
# 2025-10-29 10:17:31,235 | INFO | ID 1714 → sauvegardé: out/id_1714.json
# 2025-10-29 10:17:31,908 | INFO | ID 1715 → sauvegardé: out/id_1715.json
# 2025-10-29 10:17:32,597 | INFO | ID 1716 → sauvegardé: out/id_1716.json
# 2025-10-29 10:17:33,269 | INFO | ID 1717 → sauvegardé: out/id_1717.json
# 2025-10-29 10:17:33,944 | INFO | ID 1718 → sauvegardé: out/id_1718.json
# 2025-10-29 10:17:34,633 | INFO | ID 1719 → sauvegardé: out/id_1719.json
# 2025-10-29 10:17:35,321 | INFO | ID 1720 → sauvegardé: out/id_1720.json
# 2025-10-29 10:17:36,011 | INFO | ID 1721 → sauvegardé: out/id_1721.json
# 2025-10-29 10:17:36,700 | INFO | ID 1722 → sauvegardé: out/id_1722.json
# 2025-10-29 10:17:37,388 | INFO | ID 1723 → sauvegardé: out/id_1723.json
# 2025-10-29 10:17:38,061 | INFO | ID 1724 → sauvegardé: out/id_1724.json
# 2025-10-29 10:17:38,750 | INFO | ID 1725 → sauvegardé: out/id_1725.json
# 2025-10-29 10:17:39,438 | INFO | ID 1726 → sauvegardé: out/id_1726.json
# 2025-10-29 10:17:40,144 | INFO | ID 1727 → sauvegardé: out/id_1727.json
# 2025-10-29 10:17:40,832 | INFO | ID 1728 → sauvegardé: out/id_1728.json
# 2025-10-29 10:17:41,506 | INFO | ID 1729 → sauvegardé: out/id_1729.json
# 2025-10-29 10:17:42,195 | INFO | ID 1730 → sauvegardé: out/id_1730.json
# 2025-10-29 10:17:42,884 | INFO | ID 1731 → sauvegardé: out/id_1731.json
# 2025-10-29 10:17:43,572 | INFO | ID 1732 → sauvegardé: out/id_1732.json
# 2025-10-29 10:17:44,246 | INFO | ID 1733 → sauvegardé: out/id_1733.json
# 2025-10-29 10:17:44,935 | INFO | ID 1734 → sauvegardé: out/id_1734.json
# 2025-10-29 10:17:45,623 | INFO | ID 1735 → sauvegardé: out/id_1735.json
# 2025-10-29 10:17:46,295 | INFO | ID 1736 → sauvegardé: out/id_1736.json
# 2025-10-29 10:17:46,970 | INFO | ID 1737 → sauvegardé: out/id_1737.json
# 2025-10-29 10:17:47,658 | INFO | ID 1738 → sauvegardé: out/id_1738.json
# 2025-10-29 10:17:48,346 | INFO | ID 1739 → sauvegardé: out/id_1739.json
# 2025-10-29 10:17:49,004 | INFO | ID 1740 → sauvegardé: out/id_1740.json
# 2025-10-29 10:17:49,695 | INFO | ID 1741 → sauvegardé: out/id_1741.json
# 2025-10-29 10:17:50,382 | INFO | ID 1742 → sauvegardé: out/id_1742.json
# 2025-10-29 10:17:51,070 | INFO | ID 1743 → sauvegardé: out/id_1743.json
# 2025-10-29 10:17:51,744 | INFO | ID 1744 → sauvegardé: out/id_1744.json
# 2025-10-29 10:17:52,433 | INFO | ID 1745 → sauvegardé: out/id_1745.json
# 2025-10-29 10:17:53,105 | INFO | ID 1746 → sauvegardé: out/id_1746.json
# 2025-10-29 10:17:53,779 | INFO | ID 1747 → sauvegardé: out/id_1747.json
# 2025-10-29 10:17:54,467 | INFO | ID 1748 → sauvegardé: out/id_1748.json
# 2025-10-29 10:17:55,141 | INFO | ID 1749 → sauvegardé: out/id_1749.json
# 2025-10-29 10:17:55,829 | INFO | ID 1750 → sauvegardé: out/id_1750.json
# 2025-10-29 10:17:56,518 | INFO | ID 1751 → sauvegardé: out/id_1751.json
# 2025-10-29 10:17:57,207 | INFO | ID 1752 → sauvegardé: out/id_1752.json
# 2025-10-29 10:17:57,881 | INFO | ID 1753 → sauvegardé: out/id_1753.json
# 2025-10-29 10:17:58,570 | INFO | ID 1754 → sauvegardé: out/id_1754.json
# 2025-10-29 10:17:59,259 | INFO | ID 1755 → sauvegardé: out/id_1755.json
# 2025-10-29 10:18:00,403 | INFO | ID 1756 → sauvegardé: out/id_1756.json
# 2025-10-29 10:18:01,073 | INFO | ID 1757 → sauvegardé: out/id_1757.json
# 2025-10-29 10:18:01,746 | INFO | ID 1758 → sauvegardé: out/id_1758.json
# 2025-10-29 10:18:02,423 | INFO | ID 1759 → sauvegardé: out/id_1759.json
# 2025-10-29 10:18:03,111 | INFO | ID 1760 → sauvegardé: out/id_1760.json
# 2025-10-29 10:18:03,798 | INFO | ID 1761 → sauvegardé: out/id_1761.json
# 2025-10-29 10:18:04,460 | INFO | ID 1762 → sauvegardé: out/id_1762.json
# 2025-10-29 10:18:05,146 | INFO | ID 1763 → sauvegardé: out/id_1763.json
# 2025-10-29 10:18:05,819 | INFO | ID 1764 → sauvegardé: out/id_1764.json
# 2025-10-29 10:18:06,508 | INFO | ID 1765 → sauvegardé: out/id_1765.json
# 2025-10-29 10:18:07,197 | INFO | ID 1766 → sauvegardé: out/id_1766.json
# 2025-10-29 10:18:07,870 | INFO | ID 1767 → sauvegardé: out/id_1767.json
# 2025-10-29 10:18:08,558 | INFO | ID 1768 → sauvegardé: out/id_1768.json
# 2025-10-29 10:18:09,232 | INFO | ID 1769 → sauvegardé: out/id_1769.json
# 2025-10-29 10:18:09,922 | INFO | ID 1770 → sauvegardé: out/id_1770.json
# 2025-10-29 10:18:10,610 | INFO | ID 1771 → sauvegardé: out/id_1771.json
# 2025-10-29 10:18:11,283 | INFO | ID 1772 → sauvegardé: out/id_1772.json
# 2025-10-29 10:18:11,961 | INFO | ID 1773 → sauvegardé: out/id_1773.json
# 2025-10-29 10:18:12,644 | INFO | ID 1774 → sauvegardé: out/id_1774.json
# 2025-10-29 10:18:13,308 | INFO | ID 1775 → sauvegardé: out/id_1775.json
# 2025-10-29 10:18:13,991 | INFO | ID 1776 → sauvegardé: out/id_1776.json
# 2025-10-29 10:18:14,680 | INFO | ID 1777 → sauvegardé: out/id_1777.json
# 2025-10-29 10:18:15,370 | INFO | ID 1778 → sauvegardé: out/id_1778.json
# 2025-10-29 10:18:16,058 | INFO | ID 1779 → sauvegardé: out/id_1779.json
# 2025-10-29 10:18:16,746 | INFO | ID 1780 → sauvegardé: out/id_1780.json
# 2025-10-29 10:18:17,407 | INFO | ID 1781 → sauvegardé: out/id_1781.json
# 2025-10-29 10:18:18,076 | INFO | ID 1782 → sauvegardé: out/id_1782.json
# 2025-10-29 10:18:18,765 | INFO | ID 1783 → sauvegardé: out/id_1783.json
# 2025-10-29 10:18:19,455 | INFO | ID 1784 → sauvegardé: out/id_1784.json
# 2025-10-29 10:18:20,142 | INFO | ID 1785 → sauvegardé: out/id_1785.json
# 2025-10-29 10:18:20,832 | INFO | ID 1786 → sauvegardé: out/id_1786.json
# 2025-10-29 10:18:21,492 | INFO | ID 1787 → sauvegardé: out/id_1787.json
# 2025-10-29 10:18:22,177 | INFO | ID 1788 → sauvegardé: out/id_1788.json
# 2025-10-29 10:18:22,867 | INFO | ID 1789 → sauvegardé: out/id_1789.json
# 2025-10-29 10:18:23,555 | INFO | ID 1790 → sauvegardé: out/id_1790.json
# 2025-10-29 10:18:24,244 | INFO | ID 1791 → sauvegardé: out/id_1791.json
# 2025-10-29 10:18:24,932 | INFO | ID 1792 → sauvegardé: out/id_1792.json
# 2025-10-29 10:18:25,620 | INFO | ID 1793 → sauvegardé: out/id_1793.json
# 2025-10-29 10:18:26,293 | INFO | ID 1794 → sauvegardé: out/id_1794.json
# 2025-10-29 10:18:26,986 | INFO | ID 1795 → sauvegardé: out/id_1795.json
# 2025-10-29 10:18:27,670 | INFO | ID 1796 → sauvegardé: out/id_1796.json
# 2025-10-29 10:18:28,343 | INFO | ID 1797 → sauvegardé: out/id_1797.json
# 2025-10-29 10:18:29,016 | INFO | ID 1798 → sauvegardé: out/id_1798.json
# 2025-10-29 10:18:29,704 | INFO | ID 1799 → sauvegardé: out/id_1799.json
# 2025-10-29 10:18:30,378 | INFO | ID 1800 → sauvegardé: out/id_1800.json
# 2025-10-29 10:18:31,040 | INFO | ID 1801 → sauvegardé: out/id_1801.json
# 2025-10-29 10:18:31,726 | INFO | ID 1802 → sauvegardé: out/id_1802.json
# 2025-10-29 10:18:32,400 | INFO | ID 1803 → sauvegardé: out/id_1803.json
# 2025-10-29 10:18:33,086 | INFO | ID 1804 → sauvegardé: out/id_1804.json
# 2025-10-29 10:18:33,774 | INFO | ID 1805 → sauvegardé: out/id_1805.json
# 2025-10-29 10:18:34,448 | INFO | ID 1806 → sauvegardé: out/id_1806.json
# 2025-10-29 10:18:35,138 | INFO | ID 1807 → sauvegardé: out/id_1807.json
# 2025-10-29 10:18:35,827 | INFO | ID 1808 → sauvegardé: out/id_1808.json
# 2025-10-29 10:18:36,502 | INFO | ID 1809 → sauvegardé: out/id_1809.json
# 2025-10-29 10:18:37,188 | INFO | ID 1810 → sauvegardé: out/id_1810.json
# 2025-10-29 10:18:37,875 | INFO | ID 1811 → sauvegardé: out/id_1811.json
# 2025-10-29 10:18:38,564 | INFO | ID 1812 → sauvegardé: out/id_1812.json
# 2025-10-29 10:18:39,238 | INFO | ID 1813 → sauvegardé: out/id_1813.json
# 2025-10-29 10:18:39,910 | INFO | ID 1814 → sauvegardé: out/id_1814.json
# 2025-10-29 10:18:40,585 | INFO | ID 1815 → sauvegardé: out/id_1815.json
# 2025-10-29 10:18:41,257 | INFO | ID 1816 → sauvegardé: out/id_1816.json
# 2025-10-29 10:18:41,946 | INFO | ID 1817 → sauvegardé: out/id_1817.json
# 2025-10-29 10:18:42,619 | INFO | ID 1818 → sauvegardé: out/id_1818.json
# 2025-10-29 10:18:43,292 | INFO | ID 1819 → sauvegardé: out/id_1819.json
# 2025-10-29 10:18:43,965 | INFO | ID 1820 → sauvegardé: out/id_1820.json
# 2025-10-29 10:18:44,640 | INFO | ID 1821 → sauvegardé: out/id_1821.json
# 2025-10-29 10:18:45,327 | INFO | ID 1822 → sauvegardé: out/id_1822.json
# 2025-10-29 10:18:46,002 | INFO | ID 1823 → sauvegardé: out/id_1823.json
# 2025-10-29 10:18:46,693 | INFO | ID 1824 → sauvegardé: out/id_1824.json
# 2025-10-29 10:18:47,378 | INFO | ID 1825 → sauvegardé: out/id_1825.json
# 2025-10-29 10:18:48,070 | INFO | ID 1826 → sauvegardé: out/id_1826.json
# 2025-10-29 10:18:48,742 | INFO | ID 1827 → sauvegardé: out/id_1827.json
# 2025-10-29 10:18:49,431 | INFO | ID 1828 → sauvegardé: out/id_1828.json
# 2025-10-29 10:18:50,104 | INFO | ID 1829 → sauvegardé: out/id_1829.json
# 2025-10-29 10:18:50,793 | INFO | ID 1830 → sauvegardé: out/id_1830.json
# 2025-10-29 10:18:51,481 | INFO | ID 1831 → sauvegardé: out/id_1831.json
# 2025-10-29 10:18:52,153 | INFO | ID 1832 → sauvegardé: out/id_1832.json
# 2025-10-29 10:18:52,827 | INFO | ID 1833 → sauvegardé: out/id_1833.json
# 2025-10-29 10:18:53,517 | INFO | ID 1834 → sauvegardé: out/id_1834.json
# 2025-10-29 10:18:54,206 | INFO | ID 1835 → sauvegardé: out/id_1835.json
# 2025-10-29 10:18:54,879 | INFO | ID 1836 → sauvegardé: out/id_1836.json
# 2025-10-29 10:18:55,552 | INFO | ID 1837 → sauvegardé: out/id_1837.json
# 2025-10-29 10:18:56,226 | INFO | ID 1838 → sauvegardé: out/id_1838.json
# 2025-10-29 10:18:56,898 | INFO | ID 1839 → sauvegardé: out/id_1839.json
# 2025-10-29 10:18:57,587 | INFO | ID 1840 → sauvegardé: out/id_1840.json
# 2025-10-29 10:18:58,258 | INFO | ID 1841 → sauvegardé: out/id_1841.json
# 2025-10-29 10:18:58,933 | INFO | ID 1842 → sauvegardé: out/id_1842.json
# 2025-10-29 10:18:59,622 | INFO | ID 1843 → sauvegardé: out/id_1843.json
# 2025-10-29 10:19:00,311 | INFO | ID 1844 → sauvegardé: out/id_1844.json
# 2025-10-29 10:19:00,998 | INFO | ID 1845 → sauvegardé: out/id_1845.json
# 2025-10-29 10:19:01,660 | INFO | ID 1846 → sauvegardé: out/id_1846.json
# 2025-10-29 10:19:02,346 | INFO | ID 1847 → sauvegardé: out/id_1847.json
# 2025-10-29 10:19:03,034 | INFO | ID 1848 → sauvegardé: out/id_1848.json
# 2025-10-29 10:19:03,723 | INFO | ID 1849 → sauvegardé: out/id_1849.json
# 2025-10-29 10:19:04,396 | INFO | ID 1850 → sauvegardé: out/id_1850.json
# 2025-10-29 10:19:05,086 | INFO | ID 1851 → sauvegardé: out/id_1851.json
# 2025-10-29 10:19:05,774 | INFO | ID 1852 → sauvegardé: out/id_1852.json
# 2025-10-29 10:19:06,463 | INFO | ID 1853 → sauvegardé: out/id_1853.json
# 2025-10-29 10:19:07,152 | INFO | ID 1854 → sauvegardé: out/id_1854.json
# 2025-10-29 10:19:07,841 | INFO | ID 1855 → sauvegardé: out/id_1855.json
# 2025-10-29 10:19:08,529 | INFO | ID 1856 → sauvegardé: out/id_1856.json
# 2025-10-29 10:19:09,218 | INFO | ID 1857 → sauvegardé: out/id_1857.json
# 2025-10-29 10:19:09,907 | INFO | ID 1858 → sauvegardé: out/id_1858.json
# 2025-10-29 10:19:10,596 | INFO | ID 1859 → sauvegardé: out/id_1859.json
# 2025-10-29 10:19:11,269 | INFO | ID 1860 → sauvegardé: out/id_1860.json
# 2025-10-29 10:19:11,943 | INFO | ID 1861 → sauvegardé: out/id_1861.json
# 2025-10-29 10:19:12,616 | INFO | ID 1862 → sauvegardé: out/id_1862.json
# 2025-10-29 10:19:13,289 | INFO | ID 1863 → sauvegardé: out/id_1863.json
# 2025-10-29 10:19:13,978 | INFO | ID 1864 → sauvegardé: out/id_1864.json
# 2025-10-29 10:19:14,667 | INFO | ID 1865 → sauvegardé: out/id_1865.json
# 2025-10-29 10:19:15,339 | INFO | ID 1866 → sauvegardé: out/id_1866.json
# 2025-10-29 10:19:16,013 | INFO | ID 1867 → sauvegardé: out/id_1867.json
# 2025-10-29 10:19:16,702 | INFO | ID 1868 → sauvegardé: out/id_1868.json
# 2025-10-29 10:19:17,389 | INFO | ID 1869 → sauvegardé: out/id_1869.json
# 2025-10-29 10:19:18,068 | INFO | ID 1870 → sauvegardé: out/id_1870.json
# 2025-10-29 10:19:18,752 | INFO | ID 1871 → sauvegardé: out/id_1871.json
# 2025-10-29 10:19:19,425 | INFO | ID 1872 → sauvegardé: out/id_1872.json
# 2025-10-29 10:19:20,114 | INFO | ID 1873 → sauvegardé: out/id_1873.json
# 2025-10-29 10:19:20,803 | INFO | ID 1874 → sauvegardé: out/id_1874.json
# 2025-10-29 10:19:21,475 | INFO | ID 1875 → sauvegardé: out/id_1875.json
# 2025-10-29 10:19:22,165 | INFO | ID 1876 → sauvegardé: out/id_1876.json
# 2025-10-29 10:19:22,838 | INFO | ID 1877 → sauvegardé: out/id_1877.json
# 2025-10-29 10:19:23,527 | INFO | ID 1878 → sauvegardé: out/id_1878.json
# 2025-10-29 10:19:24,215 | INFO | ID 1879 → sauvegardé: out/id_1879.json
# 2025-10-29 10:19:24,893 | INFO | ID 1880 → sauvegardé: out/id_1880.json
# 2025-10-29 10:19:25,554 | INFO | ID 1881 → sauvegardé: out/id_1881.json
# 2025-10-29 10:19:26,235 | INFO | ID 1882 → sauvegardé: out/id_1882.json
# 2025-10-29 10:19:26,924 | INFO | ID 1883 → sauvegardé: out/id_1883.json
# 2025-10-29 10:19:27,596 | INFO | ID 1884 → sauvegardé: out/id_1884.json
# 2025-10-29 10:19:28,269 | INFO | ID 1885 → sauvegardé: out/id_1885.json
# 2025-10-29 10:19:28,944 | INFO | ID 1886 → sauvegardé: out/id_1886.json
# 2025-10-29 10:19:29,615 | INFO | ID 1887 → sauvegardé: out/id_1887.json
# 2025-10-29 10:19:30,289 | INFO | ID 1888 → sauvegardé: out/id_1888.json
# 2025-10-29 10:19:30,977 | INFO | ID 1889 → sauvegardé: out/id_1889.json
# 2025-10-29 10:19:31,667 | INFO | ID 1890 → sauvegardé: out/id_1890.json
# 2025-10-29 10:19:32,354 | INFO | ID 1891 → sauvegardé: out/id_1891.json
# 2025-10-29 10:19:33,028 | INFO | ID 1892 → sauvegardé: out/id_1892.json
# 2025-10-29 10:19:33,716 | INFO | ID 1893 → sauvegardé: out/id_1893.json
# 2025-10-29 10:19:34,406 | INFO | ID 1894 → sauvegardé: out/id_1894.json
# 2025-10-29 10:19:35,095 | INFO | ID 1895 → sauvegardé: out/id_1895.json
# 2025-10-29 10:19:35,767 | INFO | ID 1896 → sauvegardé: out/id_1896.json
# 2025-10-29 10:19:36,440 | INFO | ID 1897 → sauvegardé: out/id_1897.json
# 2025-10-29 10:19:37,129 | INFO | ID 1898 → sauvegardé: out/id_1898.json
# 2025-10-29 10:19:37,819 | INFO | ID 1899 → sauvegardé: out/id_1899.json
# 2025-10-29 10:19:38,508 | INFO | ID 1900 → sauvegardé: out/id_1900.json
# 2025-10-29 10:19:39,195 | INFO | ID 1901 → sauvegardé: out/id_1901.json
# 2025-10-29 10:19:39,869 | INFO | ID 1902 → sauvegardé: out/id_1902.json
# 2025-10-29 10:19:40,557 | INFO | ID 1903 → sauvegardé: out/id_1903.json
# 2025-10-29 10:19:41,218 | INFO | ID 1904 → sauvegardé: out/id_1904.json
# 2025-10-29 10:19:41,889 | INFO | ID 1905 → sauvegardé: out/id_1905.json
# 2025-10-29 10:19:42,561 | INFO | ID 1906 → sauvegardé: out/id_1906.json
# 2025-10-29 10:19:43,250 | INFO | ID 1907 → sauvegardé: out/id_1907.json
# 2025-10-29 10:19:43,923 | INFO | ID 1908 → sauvegardé: out/id_1908.json
# 2025-10-29 10:19:44,611 | INFO | ID 1909 → sauvegardé: out/id_1909.json
# 2025-10-29 10:19:45,284 | INFO | ID 1910 → sauvegardé: out/id_1910.json
# 2025-10-29 10:19:45,946 | INFO | ID 1911 → sauvegardé: out/id_1911.json
# 2025-10-29 10:19:46,631 | INFO | ID 1912 → sauvegardé: out/id_1912.json
# 2025-10-29 10:19:47,318 | INFO | ID 1913 → sauvegardé: out/id_1913.json
# 2025-10-29 10:19:47,992 | INFO | ID 1914 → sauvegardé: out/id_1914.json
# 2025-10-29 10:19:48,681 | INFO | ID 1915 → sauvegardé: out/id_1915.json
# 2025-10-29 10:19:49,372 | INFO | ID 1916 → sauvegardé: out/id_1916.json
# 2025-10-29 10:19:50,058 | INFO | ID 1917 → sauvegardé: out/id_1917.json
# 2025-10-29 10:19:50,722 | INFO | ID 1918 → sauvegardé: out/id_1918.json
# 2025-10-29 10:19:51,404 | INFO | ID 1919 → sauvegardé: out/id_1919.json
# 2025-10-29 10:19:52,092 | INFO | ID 1920 → sauvegardé: out/id_1920.json
# 2025-10-29 10:19:52,766 | INFO | ID 1921 → sauvegardé: out/id_1921.json
# 2025-10-29 10:19:53,454 | INFO | ID 1922 → sauvegardé: out/id_1922.json
# 2025-10-29 10:19:54,144 | INFO | ID 1923 → sauvegardé: out/id_1923.json
# 2025-10-29 10:19:54,817 | INFO | ID 1924 → sauvegardé: out/id_1924.json
# 2025-10-29 10:19:55,491 | INFO | ID 1925 → sauvegardé: out/id_1925.json
# 2025-10-29 10:19:56,181 | INFO | ID 1926 → sauvegardé: out/id_1926.json
# 2025-10-29 10:19:56,845 | INFO | ID 1927 → sauvegardé: out/id_1927.json
# 2025-10-29 10:19:57,526 | INFO | ID 1928 → sauvegardé: out/id_1928.json
# 2025-10-29 10:19:58,203 | INFO | ID 1929 → sauvegardé: out/id_1929.json
# 2025-10-29 10:19:58,876 | INFO | ID 1930 → sauvegardé: out/id_1930.json
# 2025-10-29 10:19:59,560 | INFO | ID 1931 → sauvegardé: out/id_1931.json
# 2025-10-29 10:20:00,247 | INFO | ID 1932 → sauvegardé: out/id_1932.json
# 2025-10-29 10:20:00,927 | INFO | ID 1933 → sauvegardé: out/id_1933.json
# 2025-10-29 10:20:01,610 | INFO | ID 1934 → sauvegardé: out/id_1934.json
# 2025-10-29 10:20:02,283 | INFO | ID 1935 → sauvegardé: out/id_1935.json
# 2025-10-29 10:20:02,956 | INFO | ID 1936 → sauvegardé: out/id_1936.json
# 2025-10-29 10:20:03,644 | INFO | ID 1937 → sauvegardé: out/id_1937.json
# 2025-10-29 10:20:04,333 | INFO | ID 1938 → sauvegardé: out/id_1938.json
# 2025-10-29 10:20:05,021 | INFO | ID 1939 → sauvegardé: out/id_1939.json
# 2025-10-29 10:20:05,696 | INFO | ID 1940 → sauvegardé: out/id_1940.json
# 2025-10-29 10:20:06,373 | INFO | ID 1941 → sauvegardé: out/id_1941.json
# 2025-10-29 10:20:07,058 | INFO | ID 1942 → sauvegardé: out/id_1942.json
# 2025-10-29 10:20:07,746 | INFO | ID 1943 → sauvegardé: out/id_1943.json
# 2025-10-29 10:20:08,436 | INFO | ID 1944 → sauvegardé: out/id_1944.json
# 2025-10-29 10:20:09,125 | INFO | ID 1945 → sauvegardé: out/id_1945.json
# 2025-10-29 10:20:09,802 | INFO | ID 1946 → sauvegardé: out/id_1946.json
# 2025-10-29 10:20:10,485 | INFO | ID 1947 → sauvegardé: out/id_1947.json
# 2025-10-29 10:20:11,175 | INFO | ID 1948 → sauvegardé: out/id_1948.json
# 2025-10-29 10:20:11,864 | INFO | ID 1949 → sauvegardé: out/id_1949.json
# 2025-10-29 10:20:12,536 | INFO | ID 1950 → sauvegardé: out/id_1950.json
# 2025-10-29 10:20:13,210 | INFO | ID 1951 → sauvegardé: out/id_1951.json
# 2025-10-29 10:20:13,898 | INFO | ID 1952 → sauvegardé: out/id_1952.json
# 2025-10-29 10:20:14,573 | INFO | ID 1953 → sauvegardé: out/id_1953.json
# 2025-10-29 10:20:15,248 | INFO | ID 1954 → sauvegardé: out/id_1954.json
# 2025-10-29 10:20:15,933 | INFO | ID 1955 → sauvegardé: out/id_1955.json
# 2025-10-29 10:20:16,624 | INFO | ID 1956 → sauvegardé: out/id_1956.json
# 2025-10-29 10:20:17,310 | INFO | ID 1957 → sauvegardé: out/id_1957.json
# 2025-10-29 10:20:17,999 | INFO | ID 1958 → sauvegardé: out/id_1958.json
# 2025-10-29 10:20:18,687 | INFO | ID 1959 → sauvegardé: out/id_1959.json
# 2025-10-29 10:20:19,360 | INFO | ID 1960 → sauvegardé: out/id_1960.json
# 2025-10-29 10:20:20,049 | INFO | ID 1961 → sauvegardé: out/id_1961.json
# 2025-10-29 10:20:20,723 | INFO | ID 1962 → sauvegardé: out/id_1962.json
# 2025-10-29 10:20:21,397 | INFO | ID 1963 → sauvegardé: out/id_1963.json
# 2025-10-29 10:20:22,071 | INFO | ID 1964 → sauvegardé: out/id_1964.json
# 2025-10-29 10:20:22,759 | INFO | ID 1965 → sauvegardé: out/id_1965.json
# 2025-10-29 10:20:23,447 | INFO | ID 1966 → sauvegardé: out/id_1966.json
# 2025-10-29 10:20:24,137 | INFO | ID 1967 → sauvegardé: out/id_1967.json
# 2025-10-29 10:20:24,825 | INFO | ID 1968 → sauvegardé: out/id_1968.json
# 2025-10-29 10:20:25,511 | INFO | ID 1969 → sauvegardé: out/id_1969.json
# 2025-10-29 10:20:26,201 | INFO | ID 1970 → sauvegardé: out/id_1970.json
# 2025-10-29 10:20:26,890 | INFO | ID 1971 → sauvegardé: out/id_1971.json
# 2025-10-29 10:20:27,578 | INFO | ID 1972 → sauvegardé: out/id_1972.json
# 2025-10-29 10:20:28,252 | INFO | ID 1973 → sauvegardé: out/id_1973.json
# 2025-10-29 10:20:28,927 | INFO | ID 1974 → sauvegardé: out/id_1974.json
# 2025-10-29 10:20:29,615 | INFO | ID 1975 → sauvegardé: out/id_1975.json
# 2025-10-29 10:20:30,303 | INFO | ID 1976 → sauvegardé: out/id_1976.json
# 2025-10-29 10:20:30,976 | INFO | ID 1977 → sauvegardé: out/id_1977.json
# 2025-10-29 10:20:31,665 | INFO | ID 1978 → sauvegardé: out/id_1978.json
# 2025-10-29 10:20:32,337 | INFO | ID 1979 → sauvegardé: out/id_1979.json
# 2025-10-29 10:20:33,027 | INFO | ID 1980 → sauvegardé: out/id_1980.json
# 2025-10-29 10:20:33,715 | INFO | ID 1981 → sauvegardé: out/id_1981.json
# 2025-10-29 10:20:34,387 | INFO | ID 1982 → sauvegardé: out/id_1982.json
# 2025-10-29 10:20:35,078 | INFO | ID 1983 → sauvegardé: out/id_1983.json
# 2025-10-29 10:20:35,766 | INFO | ID 1984 → sauvegardé: out/id_1984.json
# 2025-10-29 10:20:36,456 | INFO | ID 1985 → sauvegardé: out/id_1985.json
# 2025-10-29 10:20:37,143 | INFO | ID 1986 → sauvegardé: out/id_1986.json
# 2025-10-29 10:20:37,833 | INFO | ID 1987 → sauvegardé: out/id_1987.json
# 2025-10-29 10:20:38,519 | INFO | ID 1988 → sauvegardé: out/id_1988.json
# 2025-10-29 10:20:39,208 | INFO | ID 1989 → sauvegardé: out/id_1989.json
# 2025-10-29 10:20:39,882 | INFO | ID 1990 → sauvegardé: out/id_1990.json
# 2025-10-29 10:20:40,570 | INFO | ID 1991 → sauvegardé: out/id_1991.json
# 2025-10-29 10:20:41,233 | INFO | ID 1992 → sauvegardé: out/id_1992.json
# 2025-10-29 10:20:41,918 | INFO | ID 1993 → sauvegardé: out/id_1993.json
# 2025-10-29 10:20:42,606 | INFO | ID 1994 → sauvegardé: out/id_1994.json
# 2025-10-29 10:20:43,282 | INFO | ID 1995 → sauvegardé: out/id_1995.json
# 2025-10-29 10:20:43,967 | INFO | ID 1996 → sauvegardé: out/id_1996.json
# 2025-10-29 10:20:44,656 | INFO | ID 1997 → sauvegardé: out/id_1997.json
# 2025-10-29 10:20:45,334 | INFO | ID 1998 → sauvegardé: out/id_1998.json
# 2025-10-29 10:20:46,001 | INFO | ID 1999 → sauvegardé: out/id_1999.json
# 2025-10-29 10:20:46,677 | INFO | ID 2000 → sauvegardé: out/id_2000.json
# 2025-10-29 10:20:47,178 | INFO | Terminé. 501 ok, 0 manquants, 0 ignorés, 0 erreurs.

# %%
import folium
import json
import os

# --- Configuration ---
# Chemin vers le dossier contenant les fichiers JSON
JSON_DATA_PATH = '/content/out'
OUTPUT_MAP_FILE = 'ma_carte_avec_points.html'


# --- Création de la carte ---
# On centre la carte sur un point neutre avec un faible zoom pour voir le monde entier
m = folium.Map(location=[20, 0], zoom_start=2)


# --- Lecture des fichiers JSON et ajout des points ---
print(f"Recherche de fichiers JSON dans le dossier '{JSON_DATA_PATH}'...")
points_ajoutes = 0

# Parcourir tous les fichiers dans le dossier spécifié
for filename in os.listdir(JSON_DATA_PATH):
    if filename.endswith('.json'):
        filepath = os.path.join(JSON_DATA_PATH, filename)

        # Le bloc try/except est idéal pour ignorer les fichiers qui n'ont pas la bonne structure
        try:
            with open(filepath, 'r', encoding='utf-8') as f:
                data = json.load(f)

                # --- NOUVELLE LOGIQUE D'EXTRACTION (GeoJSON) ---
                # 1. Accéder aux coordonnées via le chemin "geometry" -> "coordinates"
                coords_lon_lat = data['geometry']['coordinates']

                # 2. VÉRIFICATION IMPORTANTE : Inverser les coordonnées
                #    GeoJSON est [longitude, latitude]
                #    Folium attend [latitude, longitude]
                #    On vérifie aussi qu'on a bien une paire de coordonnées
                if isinstance(coords_lon_lat, list) and len(coords_lon_lat) == 2:
                    coords_lat_lon = [coords_lon_lat[1], coords_lon_lat[0]]
                else:
                    # Si le format est inattendu, on lève une exception pour que le 'except' l'attrape
                    raise ValueError("Format de coordonnées invalide")

                # --- Extraire les informations pour la popup (nom, pays, etc.) ---
                # Dans GeoJSON, ces infos sont généralement dans un objet "properties"
                # On utilise .get() pour éviter les erreurs si "properties" n'existe pas
                properties = data.get('properties', {}) # Renvoie un dictionnaire vide si 'properties' n'existe pas
                # Ajouter un marqueur (un petit point) à la carte
                folium.Marker(
                    location=coords_lat_lon,
                    popup=popup_text,
                    icon=folium.Icon(color='green', icon='info-sign')
                ).add_to(m)

                print(f"-> Point ajouté pour le fichier '{filename}' ({city_name})")
                points_ajoutes += 1

        except (KeyError, TypeError, ValueError) as e:
            # Ce bloc s'exécute si une clé manque ('geometry', 'coordinates') ou si le format est mauvais
            # C'est exactement ce qu'il faut pour ignorer les fichiers sans coordonnées
            print(f"--- Fichier ignoré '{filename}': Coordonnées non trouvées ou format incorrect.")
        except Exception as e:
            # Pour attraper toute autre erreur imprévue
            print(f"Erreur inattendue avec le fichier '{filename}': {e}")


# --- Sauvegarde de la carte ---
if points_ajoutes > 0:
    m.save(OUTPUT_MAP_FILE)
    print(f"\nCarte générée avec succès ! {points_ajoutes} points ont été ajoutés.")
    print(f"Ouvrez le fichier '{OUTPUT_MAP_FILE}' dans votre navigateur.")
else:
    print("\nAucun point n'a été ajouté. Vérifiez le format de vos fichiers JSON et les chemins d'accès dans le script.")
# Out:
# Recherche de fichiers JSON dans le dossier '/content/out'...
# --- Fichier ignoré 'id_1568.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1708.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1726.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1938.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1973.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1523.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1915.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1926.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1968.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1669.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1640.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1565.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1643.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1686.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1873.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1756.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1940.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1711.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1718.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1775.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1587.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1511.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1897.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1974.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1941.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1910.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1754.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1874.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1602.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1743.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1771.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1700.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1742.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1855.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1530.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1793.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1731.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1853.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1677.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1660.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1866.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1536.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1751.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1760.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1637.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1982.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1601.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1912.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1971.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1881.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1503.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1621.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1598.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1533.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1543.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1823.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1978.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1815.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1630.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1839.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1569.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1844.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1774.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1847.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1946.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1920.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1676.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1830.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1996.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1703.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1837.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1528.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1681.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1921.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1872.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1604.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1987.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1834.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1877.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1809.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1539.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1986.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1679.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1653.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1900.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1927.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1869.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1580.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1981.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1856.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1506.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1813.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1553.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1969.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1699.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1623.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1665.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1999.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1698.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1803.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1595.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1748.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1768.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1907.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1583.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1781.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1713.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1585.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1680.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1977.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1788.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1705.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1611.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1500.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1639.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1612.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1894.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1893.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1985.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1633.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1838.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1836.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1891.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1689.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1766.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1600.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1712.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1592.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1733.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1792.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1575.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1762.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1561.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1619.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1988.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1769.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1750.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1683.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1761.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1776.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1763.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1737.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1517.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1564.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1835.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1944.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1648.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1618.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1854.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1560.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1983.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1515.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1825.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1608.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1721.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1688.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1998.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1814.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1785.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1571.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1767.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1850.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1826.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1529.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1738.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1759.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1905.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1682.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1691.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1625.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1786.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1955.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1701.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1694.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1827.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1716.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1870.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1521.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1887.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1502.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1709.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1758.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1849.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1722.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1540.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1707.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1684.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1631.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1513.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1519.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1605.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1562.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1649.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1674.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1784.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1860.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1747.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1632.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1805.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1818.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1537.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1976.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1864.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1512.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1591.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1692.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1883.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1729.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1563.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1790.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1951.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1852.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1538.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1544.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1746.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1589.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1685.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1719.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1732.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1846.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1806.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1811.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1879.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1576.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1807.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1945.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1890.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1934.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1628.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1770.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1875.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1961.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1597.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1661.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1757.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1624.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1668.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1626.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1975.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1581.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1840.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1570.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1555.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1876.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1929.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1993.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1851.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1593.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1675.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1534.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1650.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1799.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1892.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1868.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1657.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1967.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1690.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1714.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1828.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1531.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1507.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1739.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1979.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1627.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1574.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1773.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1777.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1724.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1780.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1586.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1647.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1930.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1861.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1821.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1723.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1687.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1833.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1673.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1614.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1913.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1666.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_2000.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1911.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1695.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1752.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1578.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1710.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1749.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1518.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1636.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1715.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1917.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1596.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1794.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1862.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1928.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1919.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1812.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1787.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1622.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1782.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1882.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1991.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1779.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1629.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1508.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1510.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1610.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1559.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1651.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1957.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1735.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1638.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1545.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1925.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1678.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1904.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1727.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1933.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1832.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1931.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1964.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1635.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1696.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1659.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1572.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1994.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1588.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1797.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1664.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1942.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1800.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1902.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1620.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1693.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1995.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1740.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1663.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1966.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1796.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1656.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1516.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1795.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1765.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1939.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1885.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1532.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1764.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1859.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1658.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1914.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1509.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1791.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1965.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1634.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1582.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1906.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1845.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1753.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1954.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1886.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1935.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1652.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1607.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1535.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1527.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1990.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1992.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1865.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1736.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1672.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1871.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1923.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1884.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1924.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1717.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1772.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1824.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1889.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1948.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1922.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1916.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1662.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1641.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1997.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1831.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1556.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1579.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1554.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1932.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1551.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1734.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1526.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1789.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1972.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1808.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1820.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1514.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1867.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1744.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1670.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1962.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1613.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1557.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1984.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1617.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1745.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1801.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1778.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1953.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1952.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1963.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1816.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1525.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1960.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1783.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1644.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1936.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1615.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1857.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1505.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1522.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1899.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1901.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1730.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1655.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1888.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1546.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1642.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1584.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1843.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1646.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1552.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1817.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1970.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1819.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1577.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1863.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1841.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1590.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1702.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1943.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1848.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1671.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1822.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1520.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1558.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1606.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1842.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1804.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1947.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1909.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1958.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1728.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1548.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1567.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1903.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1704.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1755.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1720.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1603.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1550.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1501.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1609.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1616.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1949.json' (Lieu inconnu)
# -> Point ajouté pour le fichier 'id_1524.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1908.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1645.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1541.json': Coordonnées non trouvées ou format incorrect.
# -> Point ajouté pour le fichier 'id_1956.json' (Lieu inconnu)
# --- Fichier ignoré 'id_1504.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1547.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1950.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1858.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1810.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1654.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1725.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1898.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1895.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1542.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1741.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1989.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1918.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1829.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1937.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1959.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1566.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1878.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1802.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1697.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1896.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1980.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1573.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1798.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1549.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1706.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1667.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1594.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1599.json': Coordonnées non trouvées ou format incorrect.
# --- Fichier ignoré 'id_1880.json': Coordonnées non trouvées ou format incorrect.
#
# Carte générée avec succès ! 58 points ont été ajoutés.
# Ouvrez le fichier 'ma_carte_avec_points.html' dans votre navigateur.
